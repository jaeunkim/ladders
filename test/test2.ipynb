# %%
import pandas as pd

def are_csv_files_identical(file1, file2):
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)
    return df1.equals(df2)

# %% [markdown]
# Verify if the files generated by test.ipynb is identical to the original ones

# %%
old1 = "/Users/jaeunkim/Downloads/kerr_coefficients.csv"
old2 = "/Users/jaeunkim/Downloads/up_to_sixth_order_coefficients.csv"

# %%
new1 = "/Users/jaeunkim/Codes/ladders/data/kerr_coefficients.csv"
new2 = "/Users/jaeunkim/Codes/ladders/data/up_to_sixth_order_coefficients.csv"

# %%
assert(are_csv_files_identical(old1, new1))

# %%
assert(are_csv_files_identical(old2, new2))
